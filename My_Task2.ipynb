# %% [markdown]
# TASK 2:
#
# This task involves using the Pandas
# library to manipulate data.
# Load a CSV file into a Pandas
# DataFrame. Perform operations like
# filtering data based on conditions, handling
# missing values, and calculating summary
# statistics.

# %%
import pandas as pd # import pandas library

# %%
df = pd.read_csv("/content/drive/MyDrive/01.Data Cleaning and Preprocessing.csv") # load csv file into pandas DataFrame

# %%
type(df) # checking Dataframe type
# Out:
# pandas.core.frame.DataFrame

# %%
df.info() # Checking Short summary detail of coulumn
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %%
df.shape # checking struture of dataframe
# Out:
# (324, 23)

# %%
df.describe() # describing fucntional summary
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  324.000000  319.000000  307.000000   308.000000   323.000000
# mean    20.635370   14.347937   87.464456  1237.837614   258.164483
# std      3.070036    1.499095    7.995012   100.593735    87.987452
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.382500   13.358000   81.823000  1193.215250   213.527000
# 50%     20.845000   14.308000   86.739000  1273.138500   271.792000
# 75%     23.032500   15.517000   92.372000  1289.196000   321.680000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     322.000000      322.000000  299.000000    323.000000    173.000000
# mean      356.904295      324.020180    1.492010    591.732260      6.140410
# std         9.209290        7.621402    0.105923     67.016351      0.081609
# ...

# %%
df = df.drop_duplicates()  # removing Duplicates in dataset
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 300    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 301    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.isnull() # Checking  Null/missing values for dataset
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0          False    False     False       False     False        False
# 1          False    False     False       False     False        False
# 2          False    False     False       False     False        False
# 3          False    False     False       False     False        False
# 4          False    False     False       False     False        False
# ..           ...      ...       ...         ...       ...          ...
# 298        False    False     False       False     False        False
# 299        False    False      True       False     False        False
# 300        False    False      True       False     False        False
# 301        False    False      True       False     False        False
# 307        False    False     False       False     False        False
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.isnull().sum()  # calculating row wise summary of sum of null/ missing values
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
# df.isnull().sum().sum() # calculating total sum of null/missing values
# Out:
# 352

# %%
df.notnull() # checking not null values in dataset
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0           True     True      True        True      True         True
# 1           True     True      True        True      True         True
# 2           True     True      True        True      True         True
# 3           True     True      True        True      True         True
# 4           True     True      True        True      True         True
# ..           ...      ...       ...         ...       ...          ...
# 298         True     True      True        True      True         True
# 299         True     True     False        True      True         True
# 300         True     True     False        True      True         True
# 301         True     True     False        True      True         True
# 307         True     True      True        True      True         True
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.notnull().sum() #calculating row wise summary of sum of not null values
# Out:
# Observation        301
# Y-Kappa            301
# ChipRate           297
# BF-CMratio         287
# BlowFlow           288
# ChipLevel4         300
# T-upperExt-2       300
# T-lowerExt-2       300
# UCZAA              277
# WhiteFlow-4        300
# AAWhiteSt-4        160
# AA-Wood-4          300
# ChipMoisture-4     300
# SteamFlow-4        300
# Lower-HeatT-3      300
# Upper-HeatT-3      300
# ChipMass-4         300
# WeakLiquorF        300
# BlackFlow-2        300
# WeakWashF          300
# SteamHeatF-3       300
# T-Top-Chips-4      300
# SulphidityL-4      160
# dtype: int64

# %%
df1 = df.fillna(value = 0) # filling or repalcing the missing or null values with some other value

# %%
df1
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df2 = df.fillna(method ='pad') # filling or repalcing the missing or null values with forward value

# %%
df2
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    15.167      85.034  1278.345      368.564
# 300    12-11:00    21.00    15.167      88.013  1307.722      278.842
# 301    12-12:00    21.40    15.167      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df3 = df.fillna(method ='bfill') # filling or repalcing the missing or null values with backward value
df3
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98    14.308      85.034  1278.345      368.564
# 300    12-11:00    21.00    14.308      88.013  1307.722      278.842
# 301    12-12:00    21.40    14.308      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# Here TASK 2 gets completed
# --------------------------------------------------------------------------------
# Additional for Outliers treatment

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df1['S.no']= 0

# %%
df1.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4 ', 'T-upperExt-2 ', 'T-lowerExt-2  ', 'UCZAA',
#        'WhiteFlow-4 ', 'AAWhiteSt-4 ', 'AA-Wood-4  ', 'ChipMoisture-4 ',
#        'SteamFlow-4 ', 'Lower-HeatT-3', 'Upper-HeatT-3 ', 'ChipMass-4 ',
#        'WeakLiquorF ', 'BlackFlow-2 ', 'WeakWashF ', 'SteamHeatF-3 ',
#        'T-Top-Chips-4 ', 'SulphidityL-4 '],
#       dtype='object')

# %%
df1.drop(['S.no'],axis = 1, inplace=True)
df1
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98     0.000      85.034  1278.345      368.564
# 300    12-11:00    21.00     0.000      88.013  1307.722      278.842
# 301    12-12:00    21.40     0.000      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df1.drop(['Observation'],axis = 1, inplace=True)
df1
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
# 299    24.98     0.000      85.034  1278.345      368.564        357.723
# 300    21.00     0.000      88.013  1307.722      278.842        357.438
# 301    21.40     0.000      85.490  1255.986      273.484        361.365
# 307    20.89    14.308      94.172  1327.832      251.120        351.263
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
q1 = df1.quantile(0.25)
q2 = df1.quantile(0.75)
IQR = q2-q1
print(IQR)
# Out:
# Y-Kappa              4.550
# ChipRate             2.233
# BF-CMratio          10.912
# BlowFlow            96.766
# ChipLevel4         105.868
# T-upperExt-2        11.994
# T-lowerExt-2         7.609
# UCZAA                0.152
# WhiteFlow-4        100.098
# AAWhiteSt-4          6.143
# AA-Wood-4            1.486
# ChipMoisture-4       2.186
# SteamFlow-4          8.840
# Lower-HeatT-3        8.585
# Upper-HeatT-3        7.852
# ChipMass-4          19.347
# WeakLiquorF        180.613
# BlackFlow-2        280.829
# WeakWashF          267.219
# SteamHeatF-3         6.903
# T-Top-Chips-4        2.044
# SulphidityL-4       30.420
# dtype: float64

# %%
df1 = df1[~((df1<(q1-1.5*IQR))|(df1>(q2+1.5*IQR))).any(axis=1)]

# %%
df1
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 5      14.23    15.350      85.518  1171.604      198.538        344.014
# 6      13.49    13.700      98.186  1243.688      116.275        346.208
# ..       ...       ...         ...       ...          ...            ...
# 276    22.70    15.517      83.008  1288.010      306.886        350.155
# 296    20.50    13.358      97.662  1304.597      377.678        347.672
# 297    20.40    14.233      89.790  1278.006      379.458        354.290
# 298    20.90    15.167      84.640  1283.706      339.440        354.803
# 307    20.89    14.308      94.172  1327.832      251.120        351.263
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...
